# %%
import numpy as np
import root_numpy
from sklearn import decomposition
import matplotlib.pyplot as plt
import scipy.io
from scipy import signal

save_keys = '/home/micael/MyWorkspace/ICA/Mixture_keys'
save_mixtures = '/home/micael/MyWorkspace/ICA/Mixtures'

# %%
# first mixture

n_stats = [100,1000,100000]
loc, scale = 0.,1.

for i_stats in n_stats:
    
    laplacian = np.reshape(np.random.laplace(loc, scale, i_stats),[1,i_stats])
    uniform = np.reshape(np.random.uniform(-2*scale,2*scale,i_stats),[1,i_stats])
    gaus = np.reshape(np.random.normal(loc,scale,i_stats),[1,i_stats])

# Create the sources to mix
    s = np.zeros([3,i_stats])
    s[0,:] = uniform
    s[1,:] = gaus
    s[2,:] = laplacian
    
    np.savetxt(save_keys+'/'+'FirstSource'+str(i_stats)+'Stats.txt', s)
    

    print laplacian.shape, uniform.shape, gaus.shape, s.shape
    if i_stats==100:
        A =  np.random.randn(s.shape[0], s.shape[0])
        np.savetxt(save_keys+'/'+'FirstMixMatrix.txt',A)
        
        x = np.dot(A,s)
        np.savetxt('FirstMixture'+str(i_stats)+'Stats.txt',x)
    else:
        
        x = np.dot(A,s)
        np.savetxt('FirstMixture'+str(i_stats)+'Stats.txt',x)
    
fig = plt.figure(figsize=(15,10))
plt.hist(s[2,:],bins=60,label='Laplacian')
plt.hist(s[1,:],bins=60,label='Gauss')
plt.hist(s[0,:],bins=60,label='Uniform')
plt.legend(fontsize = 'xx-large')
plt.grid()
plt.show()
# Out:
# (1, 100) (1, 100) (1, 100) (3, 100)
# (1, 1000) (1, 1000) (1, 1000) (3, 1000)
# (1, 100000) (1, 100000) (1, 100000) (3, 100000)

# %%
t = np.loadtxt('FirstMixture100000Stats.txt')
t.shape
# Out:
# (3, 100000)

# %%
# second mixture

n_stats = [100,1000,100000]
loc, scale = 0.,1.

for i_stats in n_stats:
    
    gaus1 = np.reshape(np.random.normal(loc, scale, i_stats),[1,i_stats])
    uniform = np.reshape(np.random.uniform(-2*scale,2*scale,i_stats),[1,i_stats])
    gaus2 = np.reshape(np.random.normal(loc,scale,i_stats),[1,i_stats])

# Create the sources to mix
    s = np.zeros([3,i_stats])
    s[0,:] = uniform
    s[1,:] = gaus1
    s[2,:] = gaus2
    
    np.savetxt(save_keys+'/'+'SecondSource'+str(i_stats)+'Stats.txt', s)
    

    print laplacian.shape, uniform.shape, gaus.shape, s.shape
    if i_stats==100:
        A =  np.random.randn(s.shape[0], s.shape[0])
        np.savetxt(save_keys+'/'+'SecondMixMatrix.txt',A)
        
        x = np.dot(A,s)
        np.savetxt('SecondMixture'+str(i_stats)+'Stats.txt',x)
    else:
        
        x = np.dot(A,s)
        np.savetxt('SecondMixture'+str(i_stats)+'Stats.txt',x)
    
fig = plt.figure(figsize=(15,10))
plt.hist(s[2,:],bins=60,label='Gauss2')
plt.hist(s[1,:],bins=60,label='Gauss1')
plt.hist(s[0,:],bins=60,label='Uniform')
plt.legend(fontsize = 'xx-large')
plt.grid()
plt.show()
# Out:
# (1, 100000) (1, 100) (1, 100000) (3, 100)
# (1, 100000) (1, 1000) (1, 100000) (3, 1000)
# (1, 100000) (1, 100000) (1, 100000) (3, 100000)

# %%
# third mixture

n_stats = [100,1000,100000]
loc, scale = 0.,1.

for i_stats in n_stats:
    
    rayleigh = np.reshape(np.random.rayleigh(scale, i_stats),[1,i_stats])
    uniform = np.reshape(np.random.uniform(-2*scale,2*scale,i_stats),[1,i_stats])
    gaus = np.reshape(np.random.normal(loc,scale,i_stats),[1,i_stats])

# Create the sources to mix
    s = np.zeros([3,i_stats])
    s[0,:] = uniform
    s[1,:] = rayleigh
    s[2,:] = gaus
    
    np.savetxt(save_keys+'/'+'ThirdSource'+str(i_stats)+'Stats.txt', s)
    

    print laplacian.shape, uniform.shape, gaus.shape, s.shape
    if i_stats==100:
        A =  np.random.randn(s.shape[0], s.shape[0])
        np.savetxt(save_keys+'/'+'ThirdMixMatrix.txt',A)
        
        x = np.dot(A,s)
        np.savetxt('ThirdMixture'+str(i_stats)+'Stats.txt',x)
    else:
        
        x = np.dot(A,s)
        np.savetxt('ThirdMixture'+str(i_stats)+'Stats.txt',x)
    
fig = plt.figure(figsize=(15,10))
plt.hist(s[2,:],bins=60,label='Gauss')
plt.hist(s[1,:],bins=60,label='rayleigh')
plt.hist(s[0,:],bins=60,label='Uniform')
plt.legend(fontsize = 'xx-large')
plt.grid()
plt.show()
# Out:
# (1, 100000) (1, 100) (1, 100) (3, 100)
# (1, 100000) (1, 1000) (1, 1000) (3, 1000)
# (1, 100000) (1, 100000) (1, 100000) (3, 100000)

# %%
# fourth mixture

n_stats = [100,1000,100000]
loc, scale = 0.,1.

for i_stats in n_stats:
    
    rayleigh = np.reshape(np.random.rayleigh(scale, i_stats),[1,i_stats])
    uniform = np.reshape(np.random.uniform(-2*scale,2*scale,i_stats),[1,i_stats])
    gaus = np.reshape(np.random.normal(loc,scale,i_stats),[1,i_stats])
    laplacian = np.reshape(np.random.laplace(loc, scale, i_stats),[1,i_stats])
    chi = np.reshape(np.random.chisquare(4, i_stats),[1,i_stats])

# Create the sources to mix
    s = np.zeros([5,i_stats])
    s[0,:] = uniform
    s[1,:] = rayleigh
    s[2,:] = gaus
    s[3,:] = laplacian
    s[4,:] = chi
    
    np.savetxt(save_keys+'/'+'FourthSource'+str(i_stats)+'Stats.txt', s)
    

    print laplacian.shape, uniform.shape, gaus.shape, s.shape
    if i_stats==100:
        A =  np.random.randn(s.shape[0], s.shape[0])
        np.savetxt(save_keys+'/'+'FourthMixMatrix.txt',A)
        
        x = np.dot(A,s)
        np.savetxt('FourthMixture'+str(i_stats)+'Stats.txt',x)
    else:
        
        x = np.dot(A,s)
        np.savetxt('FourthMixture'+str(i_stats)+'Stats.txt',x)
    
fig = plt.figure(figsize=(15,10))
plt.hist(s[3,:],bins=60,label='Laplacian')
plt.hist(s[4,:],bins=60,label='Chi Squared')
plt.hist(s[2,:],bins=60,label='Gauss')
plt.hist(s[1,:],bins=60,label='rayleigh')
plt.hist(s[0,:],bins=60,label='Uniform')
plt.legend(fontsize = 'xx-large')
plt.grid()
plt.show()
# Out:
# (1, 100) (1, 100) (1, 100) (5, 100)
# (1, 1000) (1, 1000) (1, 1000) (5, 1000)
# (1, 100000) (1, 100000) (1, 100000) (5, 100000)

# %%
# fifth mixture

n_stats = [100,1000,100000]
loc, scale = 0.,1.

for i_stats in n_stats:
    
    rayleigh = np.reshape(np.random.rayleigh(scale, i_stats),[1,i_stats])
    uniform = np.reshape(np.random.uniform(-2*scale,2*scale,i_stats),[1,i_stats])
    laplacian = np.reshape(np.random.laplace(loc, scale, i_stats),[1,i_stats])
    chi = np.reshape(np.random.chisquare(4, i_stats),[1,i_stats])

# Create the sources to mix
    s = np.zeros([4,i_stats])
    s[0,:] = uniform
    s[1,:] = rayleigh
    s[2,:] = laplacian
    s[3,:] = chi
    #s[4,:] = chi
    N = 0.2 * np.random.normal(size=s.shape)  # Add noise
    np.savetxt(save_keys+'/'+'FifthSourceNoise'+str(i_stats)+'Stats.txt', N)
    np.savetxt(save_keys+'/'+'FifthSource'+str(i_stats)+'Stats.txt', s)
    

    print  s.shape
    if i_stats==100:
        A =  np.random.randn(s.shape[0], s.shape[0])
        np.savetxt(save_keys+'/'+'FifthMixMatrix.txt',A)
        
        x = np.dot(A,s) + N
        np.savetxt('FifthMixture'+str(i_stats)+'Stats.txt',x)
        print x.shape
    else:
        
        x = np.dot(A,s) + N
        np.savetxt('FifthMixture'+str(i_stats)+'Stats.txt',x)
        print x.shape
fig = plt.figure(figsize=(15,10))
plt.hist(s[2,:],bins=60,label='Laplacian')
#plt.hist(s[4,:],bins=60,label='Chi Squared')
plt.hist(s[3,:],bins=60,label='Chi')
plt.hist(s[1,:],bins=60,label='rayleigh')
plt.hist(s[0,:],bins=60,label='Uniform')
plt.legend(fontsize = 'xx-large')
plt.grid()
plt.show()
# Out:
# (4, 100)
# (4, 100)
# (4, 1000)
# (4, 1000)
# (4, 100000)
# (4, 100000)

# %%
# sixth mixture

n_stats = [100,1000,100000]
loc, scale = 0.,1.

for i_stats in n_stats:
    
    #rayleigh = np.reshape(np.random.rayleigh(scale, i_stats),[1,i_stats])
    uniform = np.reshape(np.random.uniform(-2*scale,2*scale,i_stats),[1,i_stats])
    gaus = np.reshape(np.random.normal(loc,scale,i_stats),[1,i_stats])
    laplacian = np.reshape(np.random.laplace(loc, scale, i_stats),[1,i_stats])
    chi = np.reshape(np.random.chisquare(4, i_stats),[1,i_stats])

# Create the sources to mix
    s = np.zeros([4,i_stats])
    s[0,:] = uniform
    s[1,:] = chi
    s[2,:] = gaus
    s[3,:] = laplacian
    
    
    np.savetxt(save_keys+'/'+'SixthSource'+str(i_stats)+'Stats.txt', s)
    
    x = np.tanh(s)
    np.savetxt('SixthMixture'+str(i_stats)+'Stats.txt',x)
    #print laplacian.shape, uniform.shape, gaus.shape, s.shape
    #if i_stats==100:
    #    A =  np.random.randn(s.shape[0], s.shape[0])
    #    np.savetxt(save_keys+'/'+'SixthMixMatrix.txt',A)
        
    #    x = np.dot(A,s)
    #    np.savetxt('FourthMixture'+str(i_stats)+'Stats.txt',x)
    #else:
        
    #    x = np.dot(A,s)
    #    np.savetxt('FourthMixture'+str(i_stats)+'Stats.txt',x)
    
fig = plt.figure(figsize=(15,10))
plt.hist(s[3,:],bins=60,label='Laplacian')
plt.hist(s[1,:],bins=60,label='Chi Squared')
plt.hist(s[2,:],bins=60,label='Gauss')
plt.hist(s[0,:],bins=60,label='Uniform')
plt.legend(fontsize = 'xx-large')
plt.grid()
plt.show()

# %%
k = np.loadtxt('SixthMixture100000Stats.txt')
fig = plt.figure(figsize=(15,10))
plt.hist(k[3,:],bins=60,label='Mistura 4')
plt.hist(k[1,:],bins=60,label='Mistura 2')
plt.hist(k[2,:],bins=60,label='Mistura 3')
plt.hist(k[0,:],bins=60,label='Mistura 1')
plt.legend(fontsize = 'xx-large')
plt.grid()
plt.show()

# %%
# seventh mixture

n_stats = [100,1000,100000]
loc, scale = 0.,1.

for i_stats in n_stats:
    
    laplacian = np.reshape(np.random.laplace(loc, scale, i_stats),[1,i_stats])
    uniform = np.reshape(np.random.uniform(-2*scale,2*scale,i_stats),[1,i_stats])
    gaus = np.reshape(np.random.normal(loc,scale,i_stats),[1,i_stats])
    chi = np.reshape(np.random.chisquare(4, i_stats),[1,i_stats])

# Create the sources to mix
    s = np.zeros([4,i_stats])
    s[0,:] = uniform
    s[1,:] = gaus
    s[2,:] = laplacian
    s[3,:] = chi
    
    np.savetxt(save_keys+'/'+'SeventhSource'+str(i_stats)+'Stats.txt', s)
    

    print s.shape
    if i_stats==100:
        A =  np.random.randn(s.shape[0], s.shape[0])
        A[1,1] = 10
        np.savetxt(save_keys+'/'+'SeventhMixMatrix.txt',A)
        
        x = np.dot(A,s)
        np.savetxt('SeventhMixture'+str(i_stats)+'Stats.txt',x)
    else:
        
        x = np.dot(A,s)
        np.savetxt('SeventhMixture'+str(i_stats)+'Stats.txt',x)
    
fig = plt.figure(figsize=(15,10))
plt.hist(s[3,:],bins=60,label='Chi Squared')
plt.hist(s[2,:],bins=60,label='Laplacian')
plt.hist(s[1,:],bins=60,label='Gauss')
plt.hist(s[0,:],bins=60,label='Uniform')
plt.legend(fontsize = 'xx-large')
plt.grid()
plt.show()
# Out:
# (4, 100)
# (4, 1000)
# (4, 100000)

# %%
# eighth mixture

n_stats = [100,1000,100000]
loc, scale = 0.,1.

for i_stats in n_stats:
    
    rayleigh = np.reshape(np.random.rayleigh(scale, i_stats),[1,i_stats])
    uniform = np.reshape(np.random.uniform(-2*scale,2*scale,i_stats),[1,i_stats])
    gaus = np.reshape(np.random.normal(loc,scale,i_stats),[1,i_stats])
    laplacian = np.reshape(np.random.laplace(loc, scale, i_stats),[1,i_stats])
    chi = np.reshape(np.random.chisquare(4, i_stats),[1,i_stats])

# Create the sources to mix
    s = np.zeros([5,i_stats])
    s[0,:] = uniform
    s[1,:] = chi
    s[2,:] = gaus
    s[3,:] = laplacian
    s[4,:] = rayleigh
    
    
    np.savetxt(save_keys+'/'+'EighthSource'+str(i_stats)+'Stats.txt', s)
    
    x = np.exp(s)
    np.savetxt('EighthMixture'+str(i_stats)+'Stats.txt',x)
    #print laplacian.shape, uniform.shape, gaus.shape, s.shape
    #if i_stats==100:
    #    A =  np.random.randn(s.shape[0], s.shape[0])
    #    np.savetxt(save_keys+'/'+'SixthMixMatrix.txt',A)
        
    #    x = np.dot(A,s)
    #    np.savetxt('FourthMixture'+str(i_stats)+'Stats.txt',x)
    #else:
        
    #    x = np.dot(A,s)
    #    np.savetxt('FourthMixture'+str(i_stats)+'Stats.txt',x)
    
fig = plt.figure(figsize=(15,10))
plt.hist(s[4,:],bins=60,label='Rayleigh')
plt.hist(s[3,:],bins=60,label='Laplacian')
plt.hist(s[1,:],bins=60,label='Chi Squared')
plt.hist(s[2,:],bins=60,label='Gauss')
plt.hist(s[0,:],bins=60,label='Uniform')
plt.legend(fontsize = 'xx-large')
plt.grid()
plt.show()

# %%
# Time mixtures
# ninth Mixture
n_stats = [100,1000,100000]

for i_stats in n_stats:
    np.random.seed(0)
    n_samples = i_stats
    time = np.linspace(0, 8, n_samples)

    s1 = np.sin(2 * time)  # Signal 1 : sinusoidal signal
    s2 = np.sign(np.sin(3 * time))  # Signal 2 : square signal
    s3 = signal.sawtooth(2 * np.pi * time)  # Signal 3: saw tooth signal

    S = np.zeros([3,i_stats])
    S[0,:] = s1
    S[1,:] = s2
    S[2,:] = s3
    print S.shape
    np.savetxt(save_keys+'/'+'NinthSource'+str(i_stats)+'Stats.txt', S)
    N = 0.2 * np.random.normal(size=S.shape)  # Add noise
    print 'noise',N.shape
    
    if i_stats==100:
        A =  2.5 * np.random.randn(S.shape[0], S.shape[0])
        np.savetxt(save_keys+'/'+'NinthMixMatrix.txt',A)
        
        x = np.dot(A,S)
        np.savetxt('NinthMixture'+str(i_stats)+'Stats.txt',x)
    else:
        
        x = np.dot(A,S)
        np.savetxt('NinthMixture'+str(i_stats)+'Stats.txt',x)
# Out:
# (3, 100)
# noise (3, 100)
# (3, 1000)
# noise (3, 1000)
# (3, 100000)
# noise (3, 100000)

# %%
# Time mixtures
# tenth Mixture
n_stats = [100,1000,100000]

for i_stats in n_stats:
    np.random.seed(0)
    n_samples = i_stats
    time = np.linspace(0, 8, n_samples)

    s1 = np.sin(3 * time)  # Signal 1 : sinusoidal signal
    s2 = np.sign(np.sin(2 * time))  # Signal 2 : square signal
    s3 = signal.sawtooth(2 * np.pi * time)  # Signal 3: saw tooth signal

    S = np.zeros([3,i_stats])
    S[0,:] = s1
    S[1,:] = s2
    S[2,:] = s3
    print S.shape
    N = 0.2 * np.random.normal(size=S.shape)  # Add noise
    s = S + N
    np.savetxt(save_keys+'/'+'TenthSource'+str(i_stats)+'Stats.txt', s)
    N = 0.2 * np.random.normal(size=S.shape)  # Add noise
    print 'noise',N.shape
    
    if i_stats==100:
        A =  4 * np.random.randn(S.shape[0], S.shape[0])
        A[1,1] = 0.5
        np.savetxt(save_keys+'/'+'TenthMixMatrix.txt',A)
        
        x = np.dot(A,s)
        np.savetxt('TenthMixture'+str(i_stats)+'Stats.txt',x)
    else:
        
        x = np.dot(A,s)
        np.savetxt('TenthMixture'+str(i_stats)+'Stats.txt',x)
# Out:
# (3, 100)
# noise (3, 100)
# (3, 1000)
# noise (3, 1000)
# (3, 100000)
# noise (3, 100000)

# %%
len(range(19))
# Out:
# 19

# %%
import rootnotes
from ROOT import *
import StatisticalAnalysis
#from ROOT import TCanvas, TFile, TPaveText
from scipy.stats import chisquare,kurtosistest,normaltest

ROOT.gROOT.Reset()
ROOT.gStyle.SetOptStat(0)

i_stats = 100000
loc, scale = 0.,1.
iterations = 8

c = rootnotes.canvas("c", (800, 600))
K = 0
K = np.reshape(np.random.uniform(-scale,scale,i_stats),[i_stats,])  
for i in range(iterations):
    K += np.reshape(np.random.uniform(-scale,scale,i_stats),[i_stats,])
    
    
    
t = StatisticalAnalysis.EstPDF(K,bins=50,mode='hist', kernel='epanechnikov', kernel_bw=0.01)

mean = np.dot(t[1],t[0].tolist())
var = np.dot(np.power((t[1]-mean),2),t[0].tolist())
norm_K = K/np.sqrt(var)
limit = np.max(norm_K)
#print np.sqrt(np.var(norm_K))
hist = TH1D('hist', 'hist', 50, -limit, limit)
root_numpy.fill_hist(hist,norm_K)

hist.Draw()

# Define a gaussian Fit
fit = TF1("fit", "gaus", -limit, limit)
fit.SetParameters(0.,1.0)
fit.SetNDF(2)
fit.SetLineColor(kRed)
fit.SetLineWidth(3)
hist.Fit("fit")

#print fit.GetChisquare()
# Fit information
fitlabel = TPaveText( 0.7, 0.6, 0.9, 0.90, 'NDC' )
fitlabel.AddText("Model: "+fit.GetName().title())
fitlabel.AddText("Mean_{Model}: "+str(round(fit.GetHistogram().GetMean(),3))+" +- "+str(round(fit.GetHistogram().GetMeanError(),3)))
fitlabel.AddText("Var_{Model}: "+str(round(fit.GetHistogram().GetRMS(),3))+" +- "+str(round(fit.GetHistogram().GetRMSError(),3)))
fitlabel.AddText("MOP_{Model}: "+str(fit.GetHistogram().GetBinCenter(fit.GetHistogram().GetMaximumBin())))
fitlabel.AddText("Skewness_{Model}: "+str(round(fit.GetHistogram().GetSkewness(),3)))
fitlabel.AddText("#chi^{2}: "+str(round(fit.GetChisquare()))+", NDF: "+str(fit.GetNDF()))
fitlabel.AddText("Prob: "+str(100*fit.GetProb()))
fitlabel.Draw()
if 0.4 < fit.GetProb() < 0.49:
    print 'Ja deu!'
print 'Chi-Squared', fit.GetChisquare()
c
# Out:
# EstPDF: Histogram Mode
# Chi-Squared 131.176703157
# TROOT::Append:0: RuntimeWarning: Replacing existing TH1: hist (Potential memory leak).
# <ROOT.TCanvas object ("c") at 0x52decb0>

# %%
fit.GetChisquare()
# Out:
# 45.892071402169215

# %%
np.save(save_keys+'/'+'SomaUniformes.npy',norm_K)
norm_K
# Out:
# array([ 1.50702365,  1.14458007,  1.84064422, ..., -0.83981766,
#        -0.80403262, -0.72078552])

# %%
K.shape
# Out:
# (100000,)

# %%
test = np.reshape(K,[1,100000])
test.shape
ok = test[:,0:100]
ok.shape
# Out:
# (1, 100)

# %%
# eleventh mixture 
n_stats = [100,1000,100000]
loc, scale = 0.,1.


somaUniformes = np.reshape(norm_K,[1,100000])
for i_stats in n_stats:
    
    rayleigh = np.reshape(np.random.rayleigh(scale, i_stats),[1,i_stats])
    #uniform = np.reshape(np.random.uniform(-2*scale,2*scale,i_stats),[1,i_stats])
    #gaus = np.reshape(np.random.normal(loc,scale,i_stats),[1,i_stats])
    laplacian = np.reshape(np.random.laplace(loc, scale, i_stats),[1,i_stats])
    chi = np.reshape(np.random.chisquare(4, i_stats),[1,i_stats])
    
# Create the sources to mix
    s = np.zeros([4,i_stats])
    #s[0,:] = uniform
    s[0,:] = rayleigh
    s[1,:] = somaUniformes[:,0:i_stats]
    s[2,:] = laplacian
    s[3,:] = chi
    print s[2,:].shape
    np.savetxt(save_keys+'/'+'EleventhSource'+str(i_stats)+'Stats.txt', s)
    

    print laplacian.shape, uniform.shape, s.shape
    if i_stats==100:
        A =  np.random.randn(s.shape[0], s.shape[0])
        np.savetxt(save_keys+'/'+'EleventhMixMatrix.txt',A)
        
        x = np.dot(A,s)
        np.savetxt('EleventhMixture'+str(i_stats)+'Stats.txt',x)
    else:
        
        x = np.dot(A,s)
        np.savetxt('EleventhMixture'+str(i_stats)+'Stats.txt',x)
    
fig = plt.figure(figsize=(15,10))
plt.hist(s[3,:],bins=60,label='Laplacian')
plt.hist(s[2,:],bins=60,label='Chi Squared')
plt.hist(s[1,:],bins=60,label='Soma Uniformes')
plt.hist(s[0,:],bins=60,label='rayleigh')
#plt.hist(s[0,:],bins=60,label='Uniform')
plt.legend(fontsize = 'xx-large')
plt.grid()
plt.show()
# Out:
# (100,)
# (1, 100) (1, 100000) (4, 100)
# (1000,)
# (1, 1000) (1, 100000) (4, 1000)
# (100000,)
# (1, 100000) (1, 100000) (4, 100000)

# %%
N = np.reshape(np.random.normal(mean,np.sqrt(var),i_stats),[i_stats,])
g = StatisticalAnalysis.EstPDF(N,bins=50,mode='hist', kernel='epanechnikov', kernel_bw=0.01)
    #print g[0]
results = chisquare(t[0].tolist(),g[0].tolist(),axis=None)
print (' chisquare(stats): %.3f chisquare(pvalue): %.3f'%(results[0],results[1]))
# Out:
# EstPDF: Histogram Mode
#  chisquare(stats): 0.254 chisquare(pvalue): 1.000

# %%
from scipy.stats import chisquare,kurtosistest,normaltest

i_stats = 100
loc, scale = 0.,1.
iterations = 4

K=0
K = np.reshape(np.random.uniform(-scale,scale,i_stats),[i_stats,])
for i in range(iterations):
    K += np.reshape(np.random.uniform(-scale,scale,i_stats),[i_stats,])
    
    t = StatisticalAnalysis.EstPDF(K,bins=50,mode='hist', kernel='epanechnikov', kernel_bw=0.01)
    
    mean = np.dot(t[1],t[0].tolist())
    var = np.dot(np.power((t[1]-mean),2),t[0].tolist())
    
    N = np.reshape(np.random.normal(mean,np.sqrt(var),i_stats),[i_stats,])
    g = StatisticalAnalysis.EstPDF(N,bins=50,mode='hist', kernel='epanechnikov', kernel_bw=0.01)
    #print g[0]
    resukts = chisquare(t[0].tolist(),g[0].tolist(),axis=None)
    print ('iteration : %d chisquare(stats): %.3f chisquare(pvalue): %.3f'%(i+1,resukts[0],resukts[1]))
    
    #print chisquare(K,np.reshape(np.random.normal(loc,scale,i_stats),[1,i_stats]),axis=None)

plt.hist(np.reshape(K,(i_stats,)),bins=50,range=(-np.max(K),np.max(K)))
plt.show()
# Out:
# EstPDF: Histogram Mode
# EstPDF: Histogram Mode
# iteration : 1 chisquare(stats): nan chisquare(pvalue): nan
# EstPDF: Histogram Mode
# EstPDF: Histogram Mode
# iteration : 2 chisquare(stats): nan chisquare(pvalue): nan
# EstPDF: Histogram Mode
# EstPDF: Histogram Mode
# iteration : 3 chisquare(stats): nan chisquare(pvalue): nan
# EstPDF: Histogram Mode
# EstPDF: Histogram Mode
# iteration : 4 chisquare(stats): nan chisquare(pvalue): nan

# %%
mean = np.dot(t[1],t[0])
var = np.dot(np.power((t[1]-mean),2),t[0])
mean,var
# Out:
# (0.063527686308931228, 1.004801874442407)

# %%
i_stats = 100000
loc, scale = 0.,1.

N_1 = np.reshape(np.random.normal(loc,scale,i_stats),[1,i_stats])
N_2 = np.reshape(np.random.normal(loc,scale,i_stats),[1,i_stats])

t_1 = StatisticalAnalysis.EstPDF(N_1,bins=50,mode='hist', kernel='epanechnikov', kernel_bw=0.01)
t_2 = StatisticalAnalysis.EstPDF(N_2,bins=50,mode='hist', kernel='epanechnikov', kernel_bw=0.01)
# Out:
# EstPDF: Histogram Mode
# EstPDF: Histogram Mode

# %%
t
# Out:
# [array([ 0.005,  0.   ,  0.003,  0.002,  0.004,  0.009,  0.005,  0.008,
#          0.015,  0.011,  0.012,  0.021,  0.024,  0.028,  0.026,  0.018,
#          0.044,  0.038,  0.037,  0.062,  0.053,  0.042,  0.047,  0.047,
#          0.05 ,  0.059,  0.044,  0.037,  0.045,  0.03 ,  0.018,  0.019,
#          0.025,  0.023,  0.019,  0.011,  0.01 ,  0.009,  0.011,  0.012,
#          0.006,  0.003,  0.002,  0.004,  0.   ,  0.   ,  0.001,  0.   ,
#          0.   ,  0.001]),
#  array([ -3.49360599e+00,  -3.33462543e+00,  -3.17564487e+00,
#          -3.01666431e+00,  -2.85768375e+00,  -2.69870319e+00,
#          -2.53972263e+00,  -2.38074207e+00,  -2.22176151e+00,
#          -2.06278095e+00,  -1.90380039e+00,  -1.74481983e+00,
#          -1.58583927e+00,  -1.42685871e+00,  -1.26787814e+00,
#          -1.10889758e+00,  -9.49917024e-01,  -7.90936464e-01,
#          -6.31955903e-01,  -4.72975343e-01,  -3.13994782e-01,
#          -1.55014222e-01,   3.96633846e-03,   1.62946899e-01,
# ...

# %%
chisquare(t_1[0],t_2[0],axis=None)
# Out:
# Power_divergenceResult(statistic=0.030058711747406524, pvalue=1.0)

# %%
plt.plot(t_1[1],t_1[0])
plt.plot(t_2[1],t_2[0])
plt.show()

# %%
plt.plot(t[1],t[0],label='4uni')
plt.plot(g[1],g[0],label='gaus')
plt.legend()
plt.show()

# %%
#print t[0].shape
N = np.reshape(np.random.normal(mean,np.sqrt(var),100000),[1,100000])
g = StatisticalAnalysis.EstPDF(N,bins=50,mode='hist', kernel='epanechnikov', kernel_bw=0.01)
#print g[0]
chisquare(t[0].tolist(),g[0].tolist(),axis=None)
# Out:
# EstPDF: Histogram Mode
# Power_divergenceResult(statistic=2.0165105184581669, pvalue=1.0)

# %%
normaltest(K.T)
# Out:
# NormaltestResult(statistic=array([ 1045.01568309]), pvalue=array([  1.19599032e-227]))

# %%
range(0,5)
# Out:
# [0, 1, 2, 3, 4]

# %%
"""
    Implementation of pdf Mixer
"""

import numpy as np
import joblib

class Stats(object):
    
    def __init__(self,n_stats=100,verbose= False):
        self.n_stats = n_stats
        self.verbose = verbose
        
    def Print(self):
        print 'pdf Mixer'
        print 'Number of Samples:' , self.n_stats
        if self.verbose:
            print 'Verbose: True'
        else:
            print 'Verbose: False'
            

class Mixer(object):
    
    
    def __init__(self, n_pdf=3, n_pdf=['gauss','laplacian','uniform'], randomize=True, dev=True):
           
        self.MixMatrix = None
        self.n_pdf = n_pdf
        self.pdf = pdf
        self.randomize = randomize
        self.dev = dev
        
        
    
    
    def Mixer(self,sources,MixMatrix,save_path):
        if MixMatrix is None:
            MixMatrix = np.random.randn(sources.shape[0], sources.shape[0])
            np.save(save_path,MixMatrix)
            
        x = np.dot(MixMatrix,sources)
        np.save(save_path,x)

# %%
k = Stats()
k.n_stats=10
k.Print()
# Out:
# pdf Mixer
# Number of Samples: 10
# Verbose: False
